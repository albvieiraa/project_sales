-- %%
-- Criar schemas (databases) para cada camada do projeto
CREATE DATABASE IF NOT EXISTS projeto_vendas_bronze COMMENT "Schema - bronze layer";
CREATE DATABASE IF NOT EXISTS projeto_vendas_silver COMMENT "Schema - silver layer";
CREATE DATABASE IF NOT EXISTS projeto_vendas_gold COMMENT "Schema - gold layer";

-- Mantém o schema default
CREATE DATABASE IF NOT EXISTS default;

-- Usar o catálogo padrão do workspace
USE CATALOG workspace;
